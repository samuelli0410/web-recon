# %%
import web_utils
import matplotlib.pyplot as plt

# %%
img_h = 1080
img_w = 1920
N = 1000
func = lambda x, y: (x ** 2 + y ** 2) / 1000
threshold_min = 10.0
threshold_max = 500.0
epsilon = 10.0

web = web_utils.sample_web(
    func,
    x_len=img_w,
    y_len=img_w,
    N=N,
    epsilon=epsilon,
    threshold_min=threshold_min,
    threshold_max=threshold_max,
)
print(f"Number of edges: {web.num_edges}")

df = web.to_df()
print(df.iloc[:10])
# Out:
# Number of edges: 3585
#             x           y          z
# 0    2.143791  -86.626640   2.646490
# 1   80.733449  -67.678828   6.236034
# 2         NaN         NaN        NaN
# 3    2.143791  -86.626640   2.646490
# 4  191.116454  133.133352  49.387708
# 5         NaN         NaN        NaN
# 6    2.143791  -86.626640   2.646490
# 7    2.116390  -25.118938  -4.226840
# 8         NaN         NaN        NaN
# 9    2.143791  -86.626640   2.646490

# %%
# plot 
web.plot()

# %%
# Save as csv files
path = "./synthetic_web"
web.save(path)

# %%
# Thick section of web
plt.ioff()
sec = web.plot_thick_plane_section(center=0.0, thickness=10.0)

# %%
plt.ioff()
web.simulate_frames(frame_thickness=3.0, num_frames=51, save_dir="./synthetic_web_frames")
# Out:
# /Users/seewoolee/Documents/development/spiderweb/web_simulator/web.py:292: RuntimeWarning:
#
# More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
